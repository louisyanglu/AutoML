# %% [markdown]
# ### 导包

# %%
import lightgbm as lgb
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from hyperopt import hp
from toad.metrics import KS

import sys
sys.path.insert(0, r'D:\projects\auto_ml')

from auto_ml import *
from features_filtering import *

# %% [markdown]
# ### 读取数据

# %%
result = pd.read_csv('data.csv')

# %% [markdown]
# ### 拆分dev与oot

# %%
dev = result[result['payout_date'].str.slice(0, 7).isin([
    '2021-12', '2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06'])]
oot = result[~result['payout_date'].str.slice(0, 7).isin([
    '2021-12', '2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06'])]
assert dev.shape[0] + oot.shape[0] == result.shape[0]

dev.set_index(['uuid', 'certno', 'custname', 'phone', 'channel_flag', 'his_overdue_date', 'occur_date', 'payout_date'], inplace=True)
oot.set_index(['uuid', 'certno', 'custname', 'phone', 'channel_flag', 'his_overdue_date', 'occur_date', 'payout_date'], inplace=True)

# %% [markdown]
# ### 字段类别

# %%
# 定义查看变量类型的方法

# %% [markdown]
# #### 查看每种类型所包含的变量数量

# %% [markdown]
# ### 剔除缺失率95、同值率95的变量

# %%
variable_quality(dev, y_label='target', check=False, iv_limit=0)

eda_info = pd.read_excel('2.变量EDA.xlsx', sheet_name='变量IV、同值率、缺失率')
eda_info['rm_reason'].value_counts(dropna=False)

# %%
dev_filtered1 = dev[eda_info[eda_info['rm_reason'].isnull()]['variable'].astype(str).values.tolist() + ['target']]
oot_filtered1 = oot[dev_filtered1.columns]

# 剔除后所包含的变量总个数
dev_filtered1.shape, oot_filtered1.shape

# %% [markdown]
# #### 查看每种类型所包含的变量数量

# %% [markdown]
# ### 剔除方差为0的变量

# %%
dev_filtered2, oot_filtered2 = VarThreshold(dev_filtered1, oot_filtered1, threshold=0)

# 剔除后所包含的变量总个数
dev_filtered2.shape, oot_filtered2.shape
# Out:
# ((65160, 1699), (27339, 1699))

# %% [markdown]
# #### 查看每种类型所包含的变量数量

# %% [markdown]
# ### 计算psi值

# %%
psi_val, psi_frame = get_psi_info(dev_filtered2, oot_filtered2)

writer = pd.ExcelWriter('变量psi.xlsx')
psi_val.to_excel(writer, sheet_name='psi val')
psi_frame.to_excel(writer, sheet_name='psi frame')
writer.save()
writer.close()
psi_val = pd.read_excel('变量psi.xlsx', sheet_name='psi val').set_index('Unnamed: 0')
del_cols = psi_val[psi_val['psi_all'] > 0.1].index.tolist()  # 0.1或0.2
cols = psi_val[psi_val['psi_all'] <= 0.1].index.tolist()

print(f"有 {len(del_cols)} 个变量不稳定，可能会被剔除，建议后续复查变量，重点检查入模变量的稳定性")

# %% [markdown]
# ### 拆分train、test、oot

# %%
X_dev = dev_filtered2.drop('target', axis=1).fillna(-99999)
y_dev = dev_filtered2['target']

X_oot = oot_filtered2.drop('target', axis=1).fillna(-99999)
y_oot = oot_filtered2['target']

X_train, X_test, y_train, y_test = train_test_split(X_dev, y_dev, random_state=68, stratify=y_dev, test_size=0.3)

# %% [markdown]
# ### 设置初始参数空间

# %%
res1 = lgb_model_exploration(X_dev, y_dev, X_oot, y_oot, seeds=range(0, 100, 1))
res1.to_excel('1.1 model exploration.xlsx')

# %%
# 设置随机种子
seed = 7

# %%
# 根据随机种子拆分数据集
X_train, X_test, y_train, y_test = train_test_split(X_dev, y_dev, random_state=seed, stratify=y_dev, test_size=0.3)

# 设置正负样本权重
if y_train.mean() < 0.05:
    scale_pos_weight = round(0.05 * len(y_train) / sum(y_train), 4)
else:
    scale_pos_weight = 1

# 初始参数
init_param = get_init_lgb_param(scale_pos_weight, seed)

# 初始参数下的模型表现
clf, res = get_init_lgb_model(X_train, y_train, X_test, y_test, X_oot, y_oot, scale_pos_weight=scale_pos_weight, seed=seed)
res

# %% [markdown]
# ### 模型变量初筛

# %%
clf.fit(X_dev, y_dev)

# 特征重要性>0的变量
rough_feat = X_dev.columns[clf.feature_importances_ > 0]
print(f"有 {len(rough_feat)} 个变量特征重要性 > 0")
# 模型表现
model_eva(clf, X_train[rough_feat], y_train, X_test[rough_feat], y_test, X_oot[rough_feat], y_oot, X_dev[rough_feat], y_dev, if_dev=True)

# %%
X_dev = X_dev[rough_feat]
X_train = X_train[rough_feat]
X_test = X_test[rough_feat]
X_oot = X_oot[rough_feat]

# %% [markdown]
# #### 查看每种类型所包含的变量数量

# %% [markdown]
# ### 决策树的属性
# - clf.booster_.current_iteration()  # Get the index of the current iteration
# - clf.booster_.feature_importance(importance_type='split')
# - clf.booster_.feature_importance(importance_type='gain')
# - clf.booster_.feature_name()  # 与feature_importance一一对应
# - lgb.plot_importance(clf, importance_type='split', max_num_features=10)
# - clf.booster_.get_leaf_output(tree_id=0, leaf_id=0)  # 获取指定树-叶子节点的输出
# - clf.booster_.get_split_value_histogram(feature='ds84')  # 获取指定变量的分割点，设置split时，返回元组(分割次数, 分割的区间)
# - lgb.plot_split_value_histogram(clf, feature='ds84')  # Feature split value histogram
# - clf.booster_.trees_to_dataframe()  # 可查看各节点的分割特征、分割收益、分割点、缺失值在左/右子节点、输出值value、二阶海塞矩阵值weight、样本数count

# %%
lgb.plot_tree(clf, tree_index=0, figsize=(20, 8), dpi=300, show_info=['split_gain', 'internal_count', 'leaf_count', 'leaf_weight', 'data_percentage'], orientation='vertical')

# %%
lgb_booster_leaf_attribute(init_param, X_train, y_train)

# %% [markdown]
# ### 第一次调参

# %%
#? 定义参数空间
param_space = {
    'n_estimators': hp.quniform('n_estimators', 100, 200, 10),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.05)),
    'max_depth':hp.quniform('max_depth', 2, 4, 1),
    'num_leaves':hp.quniform('num_leaves', 4, 15, 1),
    # 'min_split_gain': hp.uniform('min_split_gain', 0.01, 12),
    'reg_lambda':hp.uniform('reg_lambda', 1, 15),
    'reg_alpha':hp.uniform('reg_alpha', 1, 15),
    'subsample':hp.quniform('subsample', 0.6, 1.01, 0.1),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 1.01, 0.1),
    'min_child_samples': hp.quniform('min_child_samples', 400, 1800, 100),  # X_train.shape[0] * 0.8 * 0.01, X_train.shape[0] * 0.8 * 0.05, X_train.shape[0] / 8 * 0.25
    # 'scale_pos_weight': hp.uniform('scale_pos_weight', 1, 3)
}
params_best, trials = lgb_bayes_hyperopt_process(init_param, param_space, X_train, y_train, X_test, y_test)

with open('1.1 trials_result_lgb.txt', mode='w', encoding='utf8') as f:
    f.write(str(trials.trials))

bayes_df = lgb_model_bayes_opt(trials.trials, init_param, X_train, y_train, X_test, y_test, X_oot, y_oot)
bayes_df.to_excel('1.2 第1轮贝叶斯调参.xlsx', index=False)

# %%
i = 82
fixed_params_bayes = get_bayes_param_from_trail(i, trials, init_param)
fixed_params_bayes

# %% [markdown]
# #### 第1轮调参--n_estimators、learning_rate

# %%
lgb_tune_df1 = lgb_tune2(fixed_params_bayes, 'n_estimators', 'learning_rate', range(150, 180, 3), [i/1000 for i in range(20, 30, 1)], X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df1.sort_values('ks_oot', ascending=False)
# Out:
#       id1    id2  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 70  171.0   0.02  0.226111  0.184433  0.185094  0.661859  0.622015  0.614863
# 7   150.0  0.027  0.237409  0.187296  0.184996  0.668813  0.625023  0.615866
# 37  159.0  0.027  0.241037   0.18922  0.184647  0.671343  0.625668  0.616528
# 17  153.0  0.027  0.238082    0.1875  0.184586  0.669624  0.625154  0.615703
# 90  177.0   0.02  0.229477  0.185244  0.184536  0.663126  0.622355  0.614596
# ..    ...    ...       ...       ...       ...       ...       ...       ...
# 33  159.0  0.023  0.229832  0.188946  0.177413  0.663855  0.623576  0.615293
# 13  153.0  0.023  0.228569  0.188086  0.177304  0.662571  0.622903  0.614843
# 23  156.0  0.023  0.229177  0.188344  0.177229  0.663171  0.623003  0.614439
# 3   150.0  0.023  0.228056  0.186948  0.176848  0.661795  0.622711  0.614953
# 15  153.0  0.025  0.235202  0.188529  0.176596  0.666881  0.623101   0.61594
#
#      ks_dec1   ks_dec2
# 70  0.041678  0.041016
# 7   0.050113  0.052412
# 37  0.051817  0.056389
# 17  0.050582  0.053495
# 90  0.044233  0.044941
# ..       ...       ...
# 33  0.040886  0.052419
# 13  0.040483  0.051265
# 23  0.040833  0.051948
# 3   0.041108  0.051208
# 15  0.046673  0.058606
#
# [100 rows x 10 columns]

# %%
fixed_params_bayes['n_estimators'] = 170
fixed_params_bayes['learning_rate'] = 0.02

# %%
lgb_booster_leaf_attribute(fixed_params_bayes, X_train, y_train)
# Out:
#               count       weight  split_gain
# count   1313.000000  1313.000000  633.000000
# mean    5905.590251   382.722515   11.664695
# std     6612.966959   430.679714    5.106249
# min      471.000000    25.717631    0.470910
# 10%      724.000000    45.632287    5.367258
# 20%     1054.800000    68.795333    6.844834
# 30%     1633.400000   105.851275    8.610878
# 40%     2308.000000   137.980712   10.174440
# 50%     3004.000000   195.633322   11.275500
# 60%     4520.000000   294.255539   12.342580
# 70%     6704.000000   438.566974   14.000120
# 80%    10118.200000   651.483412   15.758580
# 90%    14749.000000   949.498532   18.635699
# max    36069.000000  2298.446007   31.702299

# %% [markdown]
# #### 第2轮调参--max_depth、num_leaves

# %%
lgb_tune_df2 = lgb_tune2(fixed_params_bayes, 'max_depth', 'num_leaves', range(2, 5), range(4, 16), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df2.sort_values('ks_oot', ascending=False)
# Out:
#     id1   id2  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 18  3.0  10.0  0.226547   0.18319  0.185602  0.661682  0.621844    0.6148
# 23  3.0  15.0  0.226547   0.18319  0.185602  0.661682  0.621844    0.6148
# 22  3.0  14.0  0.226547   0.18319  0.185602  0.661682  0.621844    0.6148
# 21  3.0  13.0  0.226547   0.18319  0.185602  0.661682  0.621844    0.6148
# 20  3.0  12.0  0.226547   0.18319  0.185602  0.661682  0.621844    0.6148
# 19  3.0  11.0  0.226547   0.18319  0.185602  0.661682  0.621844    0.6148
# 17  3.0   9.0  0.226547   0.18319  0.185602  0.661682  0.621844    0.6148
# 16  3.0   8.0  0.226547   0.18319  0.185602  0.661682  0.621844    0.6148
# 31  4.0  11.0  0.267002  0.179935  0.179783   0.68621  0.625992  0.616231
# 33  4.0  13.0  0.282807  0.181708   0.17953  0.696668  0.628317  0.613311
# 32  4.0  12.0  0.276689  0.179771  0.178558  0.692099   0.62553  0.615677
# 34  4.0  14.0   0.28609  0.179705  0.177108   0.69965  0.626813  0.616329
# 29  4.0   9.0  0.250973  0.185778  0.172491  0.673699  0.626163  0.614205
# 15  3.0   7.0   0.22101  0.188399  0.172287  0.656186  0.622222  0.608254
# 30  4.0  10.0  0.261264  0.184015  0.171043  0.680051  0.625043   0.61229
# 35  4.0  15.0  0.284686  0.183931  0.170761  0.700864  0.627976  0.609837
# 28  4.0   8.0   0.24183  0.185261  0.166619  0.666807  0.625511  0.608669
# 27  4.0   7.0  0.228681  0.188655  0.161605  0.658573  0.623868  0.607615
# 14  3.0   6.0  0.211906  0.183227    0.1615  0.649089  0.621462  0.604869
# 2   2.0   6.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 3   2.0   7.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 4   2.0   8.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 5   2.0   9.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 6   2.0  10.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 7   2.0  11.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 0   2.0   4.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 8   2.0  12.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 9   2.0  13.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 10  2.0  14.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 11  2.0  15.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 1   2.0   5.0   0.18201  0.163181  0.154028  0.628396  0.612877  0.597802
# 13  3.0   5.0  0.201103  0.176038  0.147515  0.640098  0.619012  0.597817
# 26  4.0   6.0  0.216735  0.186545  0.143106  0.650146  0.621935  0.594489
# 24  4.0   4.0  0.188263  0.172562  0.137877  0.629558  0.615345  0.591587
# 12  3.0   4.0  0.188263  0.172562  0.137877  0.629558  0.615345  0.591587
# 25  4.0   5.0  0.206598  0.178108  0.136937  0.640543  0.618421  0.591489
#
#      ks_dec1   ks_dec2
# 18  0.043357  0.040945
# 23  0.043357  0.040945
# 22  0.043357  0.040945
# 21  0.043357  0.040945
# 20  0.043357  0.040945
# 19  0.043357  0.040945
# 17  0.043357  0.040945
# 16  0.043357  0.040945
# 31  0.087067  0.087218
# 33  0.101099  0.103277
# 32  0.096917  0.098131
# 34  0.106385  0.108982
# 29  0.065196  0.078482
# 15  0.032611  0.048723
# 30  0.077249  0.090221
# 35  0.100755  0.113926
# 28  0.056569  0.075211
# 27  0.040026  0.067077
# 14  0.028679  0.050406
# 2   0.018829  0.027982
# 3   0.018829  0.027982
# 4   0.018829  0.027982
# 5   0.018829  0.027982
# 6   0.018829  0.027982
# 7   0.018829  0.027982
# 0   0.018829  0.027982
# 8   0.018829  0.027982
# 9   0.018829  0.027982
# 10  0.018829  0.027982
# 11  0.018829  0.027982
# 1   0.018829  0.027982
# 13  0.025064  0.053588
# 26   0.03019  0.073629
# 24  0.015702  0.050386
# 12  0.015702  0.050386
# 25   0.02849  0.069661

# %%
fixed_params_bayes['max_depth'] = 3
fixed_params_bayes['num_leaves'] = 8

# %%
lgb_booster_leaf_attribute(fixed_params_bayes, X_train, y_train)
# Out:
#               count       weight  split_gain
# count   1313.000000  1313.000000  633.000000
# mean    5905.590251   382.722515   11.664695
# std     6612.966959   430.679714    5.106249
# min      471.000000    25.717631    0.470910
# 10%      724.000000    45.632287    5.367258
# 20%     1054.800000    68.795333    6.844834
# 30%     1633.400000   105.851275    8.610878
# 40%     2308.000000   137.980712   10.174440
# 50%     3004.000000   195.633322   11.275500
# 60%     4520.000000   294.255539   12.342580
# 70%     6704.000000   438.566974   14.000120
# 80%    10118.200000   651.483412   15.758580
# 90%    14749.000000   949.498532   18.635699
# max    36069.000000  2298.446007   31.702299

# %% [markdown]
# #### 第3轮调参--min_child_weight、min_child_samples

# %%
X_train.shape[0] * 0.01, X_train.shape[0] * 0.05, X_train.shape[0] / 8 * 0.25
# Out:
# (456.12, 2280.6, 1425.375)

# %%
lgb_tune_df2 = lgb_tune1(fixed_params_bayes, 'min_child_samples', range(400, 1000, 20), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df2.sort_values('ks_oot', ascending=False)
# Out:
#        id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 5   500.0  0.226547   0.18319  0.185602  0.661682  0.621844    0.6148
# 2   440.0   0.23144  0.182672  0.181252  0.662675  0.620584  0.612685
# %%
lgb_booster_leaf_attribute(fixed_params_bayes, X_train, y_train)
# Out:
#               count       weight  split_gain
# count   1313.000000  1313.000000  633.000000
# mean    5905.590251   382.722515   11.664695
# std     6612.966959   430.679714    5.106249
# min      471.000000    25.717631    0.470910
# 10%      724.000000    45.632287    5.367258
# 20%     1054.800000    68.795333    6.844834
# 30%     1633.400000   105.851275    8.610878
# 40%     2308.000000   137.980712   10.174440
# 50%     3004.000000   195.633322   11.275500
# 60%     4520.000000   294.255539   12.342580
# 70%     6704.000000   438.566974   14.000120
# 80%    10118.200000   651.483412   15.758580
# 90%    14749.000000   949.498532   18.635699
# max    36069.000000  2298.446007   31.702299

# %% [markdown]
# #### 第4轮调参--reg_lambda、reg_alpha

# %%
lgb_tune_df3 = lgb_tune2(fixed_params_bayes, 'reg_lambda', 'reg_alpha', range(0, 10, 1), range(0, 10, 1), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df3.sort_values('ks_oot', ascending=False)
# Out:
#     id1  id2  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 73  7.0  3.0  0.227849  0.184313  0.186599  0.663497  0.622186  0.618334
# 33  3.0  3.0  0.229761  0.185963  0.186574  0.664696  0.623813  0.618122
# 93  9.0  3.0  0.229612  0.185338  0.186103  0.662929  0.622642  0.618275
# 53  5.0  3.0  0.230843  0.182822  0.185544   0.66325  0.622258  0.616478
# 15  1.0  5.0   0.22845  0.182699  0.184902    0.6631   0.62377  0.620062
# ..  ...  ...       ...       ...       ...       ...       ...       ...
# 8   0.0  8.0  0.227273  0.189244  0.169794  0.661898  0.621022  0.611486
# 96  9.0  6.0  0.227361  0.184844  0.168945  0.661168  0.621475  0.610587
# 1   0.0  1.0  0.232224  0.184842  0.168754  0.665367  0.622148  0.609079
# 80  8.0  0.0  0.228418  0.182678  0.167845  0.663716  0.624055  0.611428
# 19  1.0  9.0  0.225956  0.189704  0.166587  0.661507  0.621372   0.60991
#
#      ks_dec1   ks_dec2
# 73  0.043536  0.041249
# 33  0.043797  0.043186
# 93  0.044274  0.043509
# 53  0.048021  0.045299
# 15  0.045751  0.043549
# ..       ...       ...
# 8   0.038029  0.057479
# 96  0.042517  0.058417
# 1   0.047382   0.06347
# 80   0.04574  0.060574
# 19  0.036253  0.059369
#
# [100 rows x 10 columns]

# %%
lgb_tune_df3 = lgb_tune2(fixed_params_bayes, 'reg_lambda', 'reg_alpha', np.arange(5, 9, 0.5), np.arange(1, 5, 0.5), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df3.sort_values('ks_oot', ascending=False)
# Out:
#     id1  id2  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 30  6.5  4.0  0.230019  0.182648  0.186743  0.662661   0.62271  0.618164
# 36  7.0  3.0  0.227849  0.184313  0.186599  0.663497  0.622186  0.618334
# 35  7.0  2.5  0.231271  0.182311  0.186069  0.663549  0.622769  0.617784
# 4   5.0  3.0  0.230843  0.182822  0.185544   0.66325  0.622258  0.616478
# 33  7.0  1.5  0.229393  0.186405  0.185319  0.663975  0.623813  0.617597
# ..  ...  ...       ...       ...       ...       ...       ...       ...
# 32  7.0  1.0  0.229318  0.180547  0.175532  0.664369  0.622677  0.613643
# 5   5.0  3.5  0.229946  0.184642  0.175113   0.66308  0.622491  0.613763
# 54  8.0  4.0  0.226968  0.185549  0.175083  0.663296   0.62258  0.613219
# 17  6.0  1.5  0.231528   0.18288  0.174457  0.663923  0.622714  0.614498
# 50  8.0  2.0  0.231954  0.179794  0.173331  0.663288   0.62262  0.610777
#
#      ks_dec1   ks_dec2
# 30   0.04737  0.043275
# 36  0.043536  0.041249
# 35  0.048959  0.045202
# 4   0.048021  0.045299
# 33  0.042988  0.044073
# ..       ...       ...
# 32   0.04877  0.053786
# 5   0.045304  0.054833
# 54  0.041419  0.051885
# 17  0.048648  0.057071
# 50   0.05216  0.058623
#
# [64 rows x 10 columns]

# %%
fixed_params_bayes['reg_lambda'] = 7
fixed_params_bayes['reg_alpha'] = 3

# %% [markdown]
# #### 第5轮调参--subsample、colsample_bytree

# %%
lgb_tune_df4 = lgb_tune2(fixed_params_bayes, 'subsample', 'colsample_bytree', [(i / 20) for i in range(10, 20, 1)], [(i / 20) for i in range(10, 20, 1)], X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df4.sort_values('ks_oot', ascending=False)
# Out:
#      id1   id2  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 38  0.65   0.9  0.227849  0.184313  0.186599  0.663497  0.622186  0.618334
# 58  0.75   0.9  0.227849  0.184313  0.186599  0.663497  0.622186  0.618334
# 98  0.95   0.9  0.227849  0.184313  0.186599  0.663497  0.622186  0.618334
# 68   0.8   0.9  0.227849  0.184313  0.186599  0.663497  0.622186  0.618334
# 88   0.9   0.9  0.227849  0.184313  0.186599  0.663497  0.622186  0.618334
# ..   ...   ...       ...       ...       ...       ...       ...       ...
# 41   0.7  0.55  0.227308  0.188619  0.151211  0.662071  0.622557  0.599606
# 11  0.55  0.55  0.227308  0.188619  0.151211  0.662071  0.622557  0.599606
# 1    0.5  0.55  0.227308  0.188619  0.151211  0.662071  0.622557  0.599606
# 81   0.9  0.55  0.227308  0.188619  0.151211  0.662071  0.622557  0.599606
# 61   0.8  0.55  0.227308  0.188619  0.151211  0.662071  0.622557  0.599606
#
#      ks_dec1   ks_dec2
# 38  0.043536  0.041249
# 58  0.043536  0.041249
# 98  0.043536  0.041249
# 68  0.043536  0.041249
# 88  0.043536  0.041249
# ..       ...       ...
# 41  0.038689  0.076097
# 11  0.038689  0.076097
# 1   0.038689  0.076097
# 81  0.038689  0.076097
# 61  0.038689  0.076097
#
# [100 rows x 10 columns]

# %%
fixed_params_bayes['colsample_bytree'] = 0.9
fixed_params_bayes['subsample'] = 0.8

# %% [markdown]
# #### 第6轮调参--scale_pos_weight

# %%
# 12   1.6  0.237151  0.189168  0.168719   0.66929  0.623791  0.610896
# 9   1.45  0.236973  0.188068  0.168518  0.668464  0.623571  0.608784
# 29  2.45  0.244511  0.183196   0.16829  0.674355  0.625112  0.611677
#
#      ks_dec1   ks_dec2
# 0   0.043536  0.041249
# 30  0.057825   0.05922
# 2   0.051633  0.050063
# 24  0.051728  0.060498
# 38  0.064443  0.066465
# 39  0.064449  0.067817
# 7    0.04625  0.049151
# 15  0.057279  0.060648
# 4   0.046771  0.048586
# 21   0.05713    0.0617
# 31  0.061712  0.064905
# 5   0.045043   0.05211
# 33  0.061303  0.065626
# 36  0.064991  0.069747
# 28  0.053343  0.067059
# 8   0.051957  0.056674
# 37  0.060802  0.068425
# 11  0.046467  0.054091
# 20  0.055449  0.065525
# 34  0.057231  0.066755
# 22  0.049506  0.062659
# 26  0.055504  0.065844
# 25  0.055004  0.066185
# 14  0.050917  0.055977
# 32   0.06144  0.072224
# 23  0.057905  0.068249
# 27  0.055361  0.067651
# 17  0.054796  0.063711
# 1   0.045763  0.056115
# 3   0.044939  0.057932
# 13  0.056307  0.063951
# 16  0.054182  0.066885
# 35  0.059763  0.071558
# 10  0.049201  0.064211
# 18  0.053882  0.068777
# 6   0.049795  0.063625
# 19  0.051057  0.070358
# 12  0.047983  0.068432
# 9   0.048905  0.068455
# 29  0.061315  0.076222

# %%
fixed_params_bayes['scale_pos_weight'] = 1

# %% [markdown]
# #### 第7轮调参--random_state

# %%
lgb_tune_df6 = lgb_tune1(fixed_params_bayes, 'random_state', range(1, 100), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df6.sort_values('ks_oot',ascending=False)
# Out:
#       id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 66  67.0  0.230285  0.182515  0.190362  0.662522  0.622234  0.618705
# 90  91.0  0.230134   0.18574  0.189232  0.662317  0.623059  0.619475
# 95  96.0  0.226122   0.18131  0.188983  0.662379  0.621457  0.620346
# 75  76.0  0.226761  0.185393   0.18869  0.662241  0.622412  0.619326
# 69  70.0   0.22855  0.186478  0.187143  0.662982  0.622599  0.618038
# ..   ...       ...       ...       ...       ...       ...       ...
# 8    9.0  0.228706  0.182924  0.174563  0.663132    0.6224   0.61157
# 1    2.0  0.227635  0.184078  0.174557  0.663613  0.621517  0.615503
# 26  27.0  0.226116  0.180991  0.173338  0.661986  0.622078  0.616373
# 22  23.0   0.22842  0.179822  0.172584  0.663069  0.622339  0.613237
# 60  61.0  0.229059  0.187632  0.172584  0.662567  0.622195  0.613008
#
#      ks_dec1   ks_dec2
# 66   0.04777  0.039923
# 90  0.044394  0.040902
# 95  0.044812  0.037139
# 75  0.041369  0.038072
# 69  0.042072  0.041407
# ..       ...       ...
# 8   0.045782  0.054143
# 1   0.043557  0.053078
# 26  0.045125  0.052778
# 22  0.048599  0.055836
# 60  0.041427  0.056474
#
# [99 rows x 9 columns]

# %%
lgb_tune_df6.sort_values('ks_oot',ascending=False).head(20)
# Out:
#       id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 66  67.0  0.230285  0.182515  0.190362  0.662522  0.622234  0.618705
# 90  91.0  0.230134   0.18574  0.189232  0.662317  0.623059  0.619475
# 95  96.0  0.226122   0.18131  0.188983  0.662379  0.621457  0.620346
# 75  76.0  0.226761  0.185393   0.18869  0.662241  0.622412  0.619326
# 69  70.0   0.22855  0.186478  0.187143  0.662982  0.622599  0.618038
# 67  68.0  0.227849  0.184313  0.186599  0.663497  0.622186  0.618334
# 27  28.0  0.232172  0.184071  0.186397  0.662819  0.621752  0.618111
# 74  75.0  0.229457  0.178078  0.185939  0.662579  0.622218  0.618297
# 20  21.0  0.228129  0.184569  0.185927   0.66284  0.622549  0.618648
# 78  79.0  0.229901  0.187961  0.185417    0.6627  0.621889  0.619308
# 96  97.0  0.228255  0.181128  0.185402  0.662775  0.621997  0.618461
# 33  34.0  0.226365  0.178967  0.185394  0.662355  0.622341  0.619367
# 63  64.0  0.225984  0.184473  0.185213  0.661758   0.62174  0.619417
# 84  85.0  0.229364  0.181675  0.185165  0.662508  0.622135  0.617778
# 47  48.0  0.230241   0.18442  0.185029  0.663167  0.622514  0.618489
# 97  98.0  0.232606  0.186269  0.184983   0.66325  0.622761  0.620713
# 53  54.0  0.226671  0.185779  0.184837  0.662153  0.622279  0.618728
# 15  16.0  0.228221  0.183218  0.184631  0.662636  0.622291   0.61654
# 45  46.0  0.229524   0.18262  0.184601  0.662438  0.622482   0.61852
# 17  18.0  0.228123  0.186774  0.184096  0.662531  0.623198  0.618943
#
#      ks_dec1   ks_dec2
# 66   0.04777  0.039923
# 90  0.044394  0.040902
# 95  0.044812  0.037139
# 75  0.041369  0.038072
# 69  0.042072  0.041407
# 67  0.043536  0.041249
# 27    0.0481  0.045775
# 74  0.051379  0.043519
# 20   0.04356  0.042202
# 78   0.04194  0.044484
# 96  0.047126  0.042853
# 33  0.047398  0.040971
# 63  0.041511  0.040771
# 84  0.047689  0.044199
# 47  0.045821  0.045213
# 97  0.046336  0.047623
# 53  0.040892  0.041835
# 15  0.045003   0.04359
# 45  0.046904  0.044923
# 17  0.041349  0.044027

# %%
fixed_params_bayes['random_state'] = 76

# %% [markdown]
# ### 第二轮调参

# %%
model = LGBMClassifier(**fixed_params_bayes)
model

# %%
# 数据集切分随机种子
bayes_df = pd.DataFrame()
for i in range(200):
    X_train, X_test, y_train, y_test = train_test_split(X_dev, y_dev, random_state=i, stratify=y_dev, test_size=0.3)
    res = model_eva(model, X_train, y_train, X_test, y_test, X_oot, y_oot)
    col = ['id', 'train', 'test', 'oot', 'ks_train', 'ks_test', 'ks_oot', 'auc_train', 'auc_test', 'auc_oot']
    result = [i, y_train.mean(), y_test.mean(), y_oot.mean(), res['ks_train'], res['ks_test'], res['ks_oot'], res['auc_train'], res['auc_test'], res['auc_oot']]
    bayes_df = pd.concat([bayes_df, pd.Series(dict(zip(col, result))).to_frame().T], axis=0, ignore_index=True)
bayes_df['ks_dec1'] = bayes_df['ks_train'] - bayes_df['ks_test']
bayes_df['ks_dec2'] = bayes_df['ks_train'] - bayes_df['ks_oot']

# %%
bayes_df.sort_values('ks_oot', ascending=False).head(20)
# Out:
#         id     train      test       oot  ks_train   ks_test    ks_oot  \
# 68    68.0  0.069806  0.069777  0.055196  0.226761  0.185393  0.188690
# 4      4.0  0.069806  0.069777  0.055196  0.232768  0.185572  0.184712
# 42    42.0  0.069806  0.069777  0.055196  0.242272  0.170067  0.183103
# 73    73.0  0.069806  0.069777  0.055196  0.243384  0.156558  0.181822
# 53    53.0  0.069806  0.069777  0.055196  0.235786  0.159053  0.181791
# 34    34.0  0.069806  0.069777  0.055196  0.246899  0.149932  0.180915
# 48    48.0  0.069806  0.069777  0.055196  0.230809  0.166118  0.180136
# 38    38.0  0.069806  0.069777  0.055196  0.246502  0.162651  0.178615
# 44    44.0  0.069806  0.069777  0.055196  0.231478  0.169670  0.178560
# 162  162.0  0.069806  0.069777  0.055196  0.244731  0.163371  0.178244
# 107  107.0  0.069806  0.069777  0.055196  0.237337  0.142191  0.177672
# 132  132.0  0.069806  0.069777  0.055196  0.227263  0.159278  0.177120
# 146  146.0  0.069806  0.069777  0.055196  0.237065  0.149165  0.176969
# 179  179.0  0.069806  0.069777  0.055196  0.231954  0.156023  0.176228
# 72    72.0  0.069806  0.069777  0.055196  0.232130  0.158979  0.175520
# 13    13.0  0.069806  0.069777  0.055196  0.240802  0.155519  0.174630
# 147  147.0  0.069806  0.069777  0.055196  0.242523  0.159746  0.173993
# 192  192.0  0.069806  0.069777  0.055196  0.232433  0.168149  0.173912
# 163  163.0  0.069806  0.069777  0.055196  0.236944  0.163859  0.172951
# 24    24.0  0.069806  0.069777  0.055196  0.239638  0.147222  0.172032
#
#      auc_train  auc_test   auc_oot   ks_dec1   ks_dec2
# 68    0.662241  0.622412  0.619326  0.041369  0.038072
# 4     0.664581  0.621191  0.611675  0.047196  0.048056
# 42    0.668164  0.616256  0.619964  0.072205  0.059169
# 73    0.670333  0.602388  0.615441  0.086826  0.061562
# 53    0.666688  0.611343  0.615254  0.076732  0.053995
# 34    0.669304  0.600026  0.612349  0.096968  0.065985
# 48    0.664657  0.605065  0.611129  0.064691  0.050673
# 38    0.668156  0.615061  0.612064  0.083852  0.067887
# 44    0.667304  0.617381  0.615110  0.061808  0.052918
# 162   0.671927  0.608592  0.612483  0.081360  0.066487
# 107   0.666429  0.596084  0.611971  0.095145  0.059664
# 132   0.661036  0.605887  0.614998  0.067986  0.050144
# 146   0.665335  0.606241  0.614590  0.087900  0.060096
# 179   0.666400  0.604764  0.606635  0.075931  0.055726
# 72    0.665913  0.608046  0.613066  0.073151  0.056609
# 13    0.664546  0.608140  0.611798  0.085282  0.066172
# 147   0.671078  0.606638  0.613404  0.082777  0.068530
# 192   0.663351  0.610302  0.611551  0.064284  0.058522
# 163   0.664296  0.606132  0.608189  0.073085  0.063994
# 24    0.669204  0.602139  0.607106  0.092416  0.067606

# %%
i = 68
X_train, X_test, y_train, y_test = train_test_split(X_dev, y_dev, random_state=i, stratify=y_dev, test_size=0.3)

# %%
lgb_booster_leaf_attribute(fixed_params_bayes, X_train, y_train)

# %%
#? 定义参数空间
param_space = {
    'n_estimators': hp.quniform('n_estimators', 160, 180, 1),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.05)),
    # 'max_depth':hp.quniform('max_depth', 2, 4, 1),
    # 'num_leaves':hp.quniform('num_leaves', 4, 15, 1),
    'min_split_gain': hp.uniform('min_split_gain', 0.01, 10),
    'reg_lambda':hp.uniform('reg_lambda', 0, 10),
    'reg_alpha':hp.uniform('reg_alpha', 0, 10),
    # 'subsample':hp.quniform('subsample', 0.6, 1.01, 0.1),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 1.01, 0.1),
    'min_child_samples': hp.quniform('min_child_samples', 400, 800, 10),  # X_train.shape[0] * 0.8 * 0.01, X_train.shape[0] * 0.8 * 0.05, X_train.shape[0] / 8 * 0.25
    # 'scale_pos_weight': hp.uniform('scale_pos_weight', 1, 3)
}
params_best, trials = lgb_bayes_hyperopt_process(init_param, param_space, X_train, y_train, X_test, y_test)

with open('2.1 trials_result_lgb.txt', mode='w', encoding='utf8') as f:
    f.write(str(trials.trials))

bayes_df = lgb_model_bayes_opt(trials.trials, init_param, X_train, y_train, X_test, y_test, X_oot, y_oot)
bayes_df.to_excel('2.2 第2轮贝叶斯调参.xlsx', index=False)

# %%
fixed_params_bayes = get_bayes_param_from_trail(122, trials, init_param)
fixed_params_bayes
# Out:
# {'boosting_type': 'gbdt',
#  'max_depth': 3,
#  'learning_rate': 0.0104,
#  'objective': 'binary',
#  'scale_pos_weight': 1,
#  'min_split_gain': 2.8542,
#  'min_child_samples': 470,
#  'subsample': 0.8,
#  'colsample_bytree': 0.9,
#  'reg_lambda': 4.8839,
#  'reg_alpha': 2.1956,
#  'random_state': 68,
#  'force_col_wise': True,
#  'verbose': -1,
#  'n_estimators': 172}

# %% [markdown]
# #### 第1轮调参--n_estimators、learning_rate

# %%
lgb_tune_df1 = lgb_tune2(fixed_params_bayes, 'n_estimators', 'learning_rate', range(170, 180, 1), [i/1000 for i in range(10, 25, 1)], X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df1.sort_values('ks_oot', ascending=False)
# Out:
#       id1    id2  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 77  177.0  0.017  0.223383  0.185338  0.180024  0.658323  0.621789  0.615407
# 57  175.0  0.017  0.222966  0.184184  0.179669     0.658  0.621397  0.614845
# 67  176.0  0.017  0.222678  0.183983  0.179282   0.65824  0.621655  0.615495
# 87  178.0  0.017  0.223874  0.185558  0.179136  0.658543  0.621874  0.615403
# 38  173.0  0.018  0.229795  0.182294  0.179032  0.660514  0.622239  0.612432
# ..    ...    ...       ...       ...       ...       ...       ...       ...
# 40  174.0   0.01  0.189322  0.167754    0.1637  0.638064  0.611395  0.604448
# 75  0.037893  0.044365
# 12  0.028044  0.027759
# 55  0.040197  0.045402
# 35  0.039878  0.045034
# 42  0.027145  0.029062
# 32  0.026527  0.029389
# 92   0.02987  0.031907
# 85  0.039661  0.046521
# 52  0.026856  0.029502
# 2   0.026538  0.028819
# 72   0.02855  0.031287
# 5   0.038373  0.045068
# 82  0.029074  0.031913
# 15  0.039646  0.046592
# 62  0.028362  0.031608

# %%
fixed_params_bayes['n_estimators'] = 177
fixed_params_bayes['learning_rate'] = 0.017

# %% [markdown]
# #### 第2轮调参--max_depth、num_leaves

# %%
# lgb_tune_df2 = lgb_tune2(fixed_params_bayes, 'max_depth', 'num_leaves', range(2, 5), range(4, 16), X_train, y_train, X_test, y_test, X_oot, y_oot)
# lgb_tune_df2.sort_values('ks_oot', ascending=False)

# %%
# fixed_params_bayes['max_depth'] = 3
# fixed_params_bayes['num_leaves'] = 8

# %%
lgb_booster_leaf_attribute(fixed_params_bayes, X_train, y_train)
# Out:
#               count       weight  split_gain
# count   1334.000000  1334.000000  640.000000
# mean    6051.967016   392.233948   13.440471
# std     6872.178043   447.454050    5.504871
# min      413.000000    22.976123    2.922130
# 10%      733.300000    48.496744    6.570744
# 20%     1074.200000    68.795115    8.427786
# 30%     1568.000000   105.301066   10.226190
# 40%     2309.400000   138.629433   11.766120
# 50%     3343.000000   211.299244   12.906350
# 60%     4569.400000   296.502771   14.282860
# 70%     6288.300000   429.217091   16.102360
# 80%    10223.000000   673.119505   17.962320
# 90%    15931.000000  1026.105995   21.151110
# max    40004.000000  2613.999167   34.181099

# %% [markdown]
# #### 第3轮调参--min_child_weight、min_child_samples

# %%
X_train.shape[0] * 0.01, X_train.shape[0] * 0.05, X_train.shape[0] / 8 * 0.25
# Out:
# (456.12, 2280.6, 1425.375)

# %%
fixed_params_bayes
# Out:
# {'boosting_type': 'gbdt',
#  'max_depth': 3,
#  'learning_rate': 0.017,
#  'objective': 'binary',
#  'scale_pos_weight': 1,
#  'min_split_gain': 2.8542,
#  'min_child_samples': 470,
#  'subsample': 0.8,
#  'colsample_bytree': 0.9,
#  'reg_lambda': 4.8839,
#  'reg_alpha': 2.1956,
#  'random_state': 68,
#  'force_col_wise': True,
#  'verbose': -1,
#  'n_estimators': 177}

# %%
lgb_tune_df2 = lgb_tune1(fixed_params_bayes, 'min_child_samples', range(400, 1000, 20), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df2.sort_values('ks_oot', ascending=False)
# Out:
#        id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 21  820.0  0.222589  0.187299  0.179345   0.65637  0.621209   0.61391
# 5   500.0  0.223066  0.181383  0.177432   0.65799  0.621666  0.614394
# 3   460.0  0.223046  0.182646  0.177431  0.658622  0.621428  0.616374
# 18  760.0  0.224416   0.18583  0.177296  0.657129  0.621842  0.614577
# 16  720.0  0.222036   0.18442  0.177294  0.657405  0.621912  0.614646
# 14  680.0  0.223195   0.18059  0.176996  0.657389  0.621668   0.61432
# 1   420.0  0.224419  0.179814  0.176148  0.658799  0.620914  0.614695
# 4   480.0  0.224313  0.180869  0.175344  0.658105  0.621138  0.616265
# 17  740.0  0.227083   0.18283  0.174901  0.657286  0.621684  0.613515
# 0   400.0  0.226777  0.182153  0.173689  0.659634  0.621128  0.614163
# 26  920.0  0.221019  0.188506   0.17326   0.65532  0.621069  0.611352
# 8   560.0  0.225064  0.182516   0.17312  0.658084  0.620631  0.609748
# 7   540.0  0.225224  0.182187   0.17301  0.658756  0.621165   0.61178
# 22  840.0  0.222313  0.185489  0.172983  0.656211  0.621119  0.611839
# 6   520.0  0.225211  0.181548   0.17254  0.658777  0.620919   0.60994
# 11  620.0  0.221519  0.180866  0.172463  0.658127  0.621009  0.610619
# 25  900.0  0.224407  0.183208  0.172327  0.655894  0.620301  0.610497
# 24  880.0  0.222914  0.187303  0.172048  0.655547  0.619952  0.610844
# 12  640.0   0.22404  0.180757  0.171613   0.65777  0.621137  0.611537
# 20  800.0   0.22518  0.186342  0.171455  0.656868  0.621065  0.609959
# 9   580.0  0.223097  0.185288  0.171252  0.658644   0.62062  0.610688
# 10  600.0  0.224824  0.182703  0.171044  0.658024   0.62064    0.6088
# 15  700.0  0.224172  0.182828  0.170936   0.65751  0.621946  0.610278
# 2   440.0  0.224678  0.179434  0.170087  0.658378  0.620818  0.612342
# 13  660.0  0.223376  0.179889  0.170026   0.65799   0.62089  0.611019
# 27  940.0  0.223208  0.188269  0.169645  0.655881  0.620939  0.607985
# 23  860.0  0.222927  0.184682  0.169576  0.656015  0.620961  0.610711
# 19  780.0  0.223855  0.186359  0.169221   0.65729  0.621068  0.611013
# 28  960.0  0.220097   0.18321  0.168982  0.655205   0.62026  0.608593
# 29  980.0  0.221936   0.18277  0.166117  0.655165  0.620734  0.607746
#
#      ks_dec1   ks_dec2
# 21   0.03529  0.043244
# 5   0.041683  0.045634
# 3     0.0404  0.045615
# 18  0.038586   0.04712
# 16  0.037616  0.044741
# 14  0.042605  0.046198
# 1   0.044605  0.048271
# 4   0.043445  0.048969
# 17  0.044254  0.052183
# 0   0.044624  0.053088
# 26  0.032514   0.04776
# 8   0.042548  0.051944
# 7   0.043037  0.052214
# 22  0.036824   0.04933
# 6   0.043663   0.05267
# 11  0.040653  0.049057
# 25  0.041198   0.05208
# 24  0.035611  0.050865
# 12  0.043283  0.052427
# 20  0.038838  0.053726
# 9   0.037809  0.051844
# 10  0.042121  0.053781
# 15  0.041344  0.053236
# 2   0.045244  0.054592
# 13  0.043487   0.05335
# 27  0.034939  0.053563
# 23  0.038246  0.053351
# 19  0.037496  0.054634
# 28  0.036887  0.051115
# 29  0.039166  0.055819

# %%
lgb_tune_df2 = lgb_tune1(fixed_params_bayes, 'min_child_samples', range(500, 800, 10), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df2.sort_values('ks_oot', ascending=False)
# Out:
#        id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 7   0.043578  0.058083
# 19  0.041572  0.055141
# 9   0.038082  0.057258
# 17  0.040851   0.05905

# %%
fixed_params_bayes['min_child_samples'] = 790

# %%
lgb_booster_leaf_attribute(fixed_params_bayes, X_train, y_train)
# Out:
#               count       weight  split_gain
# count   1310.000000  1310.000000  618.000000
# mean    6162.842748   399.474516   13.413876
# std     6889.476898   449.078694    5.717817
# min      746.000000    42.465444    3.002820
# 10%      926.900000    60.520387    5.837099
# 20%     1185.000000    80.691552    8.009412
# 30%     1770.000000   111.441027   10.311760
# 40%     2389.000000   142.530723   12.055140
# 50%     3284.000000   211.115203   13.098000
# 60%     4518.800000   292.921320   14.489440
# 70%     6393.800000   431.915489   16.278561
# 80%    10286.000000   664.524114   17.793180
# 90%    16085.200000  1036.522535   21.394880
# max    40004.000000  2614.449494   34.153599

# %% [markdown]
# #### 第4轮调参--reg_lambda、reg_alpha

# %%
lgb_tune_df3 = lgb_tune2(fixed_params_bayes, 'reg_lambda', 'reg_alpha', range(0, 10, 1), range(0, 10, 1), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df3.sort_values('ks_oot', ascending=False)
# Out:
#     id1  id2  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 30  3.0  0.0  0.222737  0.189885  0.184935  0.657573  0.622292  0.616865
# 40  4.0  0.0  0.224445  0.183853  0.183606  0.657523  0.622281  0.615934
# 70  7.0  0.0  0.222133  0.183982  0.183043  0.657024  0.622151  0.615328
# 50  5.0  0.0  0.223613  0.184842  0.182741  0.656184  0.621308   0.61723
# 51  5.0  1.0  0.223043  0.185097  0.181326  0.656617  0.622163  0.613721
# ..  ...  ...       ...       ...       ...       ...       ...       ...
# 57  5.0  7.0  0.219642  0.179176  0.152808  0.653379  0.618924  0.600482
# 59  5.0  9.0  0.215185  0.173549  0.152318   0.65194  0.617499  0.602041
# 99  9.0  9.0  0.217644  0.176392  0.150449  0.650779   0.61714  0.601146
# 39  3.0  9.0  0.216206  0.178165  0.150204  0.652148  0.618634  0.600478
# 19  1.0  9.0  0.218195   0.17804  0.146218  0.652923  0.618608  0.597502
#
#      ks_dec1   ks_dec2
# 30  0.032851  0.037801
# 40  0.040592  0.040839
# 70  0.038151   0.03909
# 50  0.038771  0.040873
# 51  0.037945  0.041717
# ..       ...       ...
# 57  0.040466  0.066835
# 59  0.041635  0.062867
# 99  0.041253  0.067195
# 39  0.038041  0.066003
# 19  0.040155  0.071977
#
# [100 rows x 10 columns]

# %%
fixed_params_bayes['reg_alpha'] = 0

# %%
lgb_tune_df3 = lgb_tune1(fixed_params_bayes, 'reg_lambda', np.arange(2, 7, 0.1), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df3.sort_values('ks_oot', ascending=False)
# Out:
#      id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot   ks_dec1  \
# 9   2.9  0.223537  0.185082  0.185824  0.657384  0.622773  0.617019  0.038454
# 36  5.6  0.224536  0.186032  0.185755  0.656344  0.622265  0.617873  0.038504
# 7   2.7  0.223582  0.183947  0.176038  0.657036  0.621474  0.613454  0.039635
# 38  5.8  0.223113  0.184496  0.175321  0.656823  0.621049  0.611386  0.038616
# 39  5.9  0.221672  0.182128  0.175316  0.656426  0.621754  0.613897  0.039544
# 2   2.2  0.226098  0.186022  0.175303  0.657195  0.621931  0.611478  0.040077
# 5   2.5  0.224602  0.183749  0.174749  0.656507  0.622033  0.613558  0.040853
# 12  3.2  0.223979  0.180704  0.174692  0.657485  0.621682  0.611126  0.043274
# 33  5.3  0.223789  0.183984  0.174462   0.65725  0.621816  0.611561  0.039805
# 6   2.6  0.224154  0.184551  0.174016   0.65683  0.621678  0.612901  0.039602
# 41  6.1   0.22477  0.186808  0.173799  0.656725  0.622784  0.613495  0.037962
# 28  4.8   0.22369  0.187229  0.173626  0.656953  0.621349  0.613143  0.036462
# 34  5.4  0.223894  0.184974  0.173439  0.656926  0.621369  0.611878   0.03892
# 48  6.8  0.225274  0.181912  0.173232  0.656841  0.621739  0.611712  0.043363
# 37  5.7  0.224429  0.179493  0.169944  0.657185  0.621927  0.610708  0.044936
#
#      ks_dec2
# 9   0.037713
# 36   0.03878
# 45  0.037754
# 10  0.037801
# 20  0.040839
# 8   0.042158
# 42  0.037362
# 18  0.039597
# 30  0.040873
# 4   0.042589
# 44  0.042689
# 23  0.040293
# 1   0.044306
# 43  0.041679
# 17  0.041669
# 47  0.042078
# 19  0.040969
# 15  0.042309
# 49   0.04192
# 31  0.042701
# 26  0.042574
# 21  0.042648
# 14  0.044719
# 0   0.046773
# 32  0.047609
# 13  0.043812
# 3    0.04625
# 16  0.043678
# 24  0.045184
# 27  0.046494
# 22  0.046589
# 25   0.04698
# 11  0.047444
# 35  0.047129
# 46  0.045481
# 40  0.045723
# 29  0.046527
# 7   0.047543
# 38  0.047792
# 39  0.046356
# 2   0.050796
# 5   0.049853
# 12  0.049286
# 33  0.049326
# 6   0.050138
# 41  0.050971
# 28  0.050064
# 34  0.050455
# 48  0.052042
# 37  0.054485

# %%
fixed_params_bayes['reg_lambda'] = 3
fixed_params_bayes['reg_alpha'] = 0

# %% [markdown]
# #### 第5轮调参--subsample、colsample_bytree

# %%
lgb_tune_df4 = lgb_tune1(fixed_params_bayes, 'colsample_bytree', [(i / 20) for i in range(10, 20, 1)], X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df4.sort_values('ks_oot', ascending=False)
# Out:
#      id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot   ks_dec1  \
# 8   0.9  0.222737  0.189885  0.184935  0.657573  0.622292  0.616865  0.032851
# 7  0.85  0.224179  0.183087  0.184683  0.656086  0.622769  0.618625  0.041092
# 9  0.95  0.224833  0.181962  0.178561   0.65693  0.621992  0.615835  0.042871
# 2   0.6  0.222584  0.186838  0.165817  0.655981  0.621793  0.603757  0.035745
# 6   0.8  0.224983  0.186093  0.164777  0.657226    0.6209  0.607068   0.03889
# 5  0.75  0.224059   0.18235  0.160245  0.657589  0.621445  0.604013  0.041709
# 3  0.65  0.223721  0.185777  0.159418  0.655962  0.621734   0.60524  0.037944
# 4   0.7  0.219784  0.182751  0.159315  0.655985  0.621499  0.603495  0.037033
# 1  0.55  0.219286  0.179729  0.152899  0.656176   0.62142  0.597448  0.039558
# 0   0.5  0.218786  0.175424  0.142597  0.654622  0.620769  0.592531  0.043362
#
#     ks_dec2
# 8  0.037801
# 7  0.039496
# 9  0.046271
# 2  0.056767
# 6  0.060205
# 5  0.063814
# 3  0.064303
# 4  0.060469
# 1  0.066388
# 0  0.076188

# %%
fixed_params_bayes['colsample_bytree'] = 0.9
fixed_params_bayes['subsample'] = 0.8

# %% [markdown]
# #### 第6轮调参--min_split_gain

# %%
lgb_tune_df4 = lgb_tune1(fixed_params_bayes, 'min_split_gain', range(0, 10), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df4.sort_values('ks_oot', ascending=False)
# Out:
#     id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot   ks_dec1  \
# 0  0.0  0.225401  0.182586   0.18549  0.657624  0.621394  0.618405  0.042815
# 1  1.0  0.222558  0.183671  0.185064  0.657345  0.621741  0.618577  0.038887
# 2  2.0  0.225126  0.187008  0.179501  0.657816  0.622931  0.616941  0.038118
# 4  4.0  0.221959  0.185031  0.176245  0.656249   0.62124  0.616182  0.036928
# 6  6.0  0.221363  0.178837   0.17425  0.652395  0.621297  0.614416  0.042526
# 3  3.0   0.22292  0.190201  0.172896  0.656337  0.621206  0.611002   0.03272
# 5  5.0  0.219057  0.181823  0.172071  0.654712  0.621103  0.614208  0.037234
# 7  7.0  0.215299  0.181162  0.165606  0.649638  0.620804  0.610107  0.034138
# 8  8.0  0.207145  0.178247  0.155845    0.6467  0.619492  0.604885  0.028899
# 9  9.0  0.207929  0.178436  0.152254  0.644541  0.618666  0.598564  0.029493
#
#     ks_dec2
# 0  0.039911
# 1  0.037494
# 2  0.045625
# 4  0.045714
# 6  0.047113
# 3  0.050025
# 5  0.046986
# 7  0.049693
# 8    0.0513
# 9  0.055675

# %%
fixed_params_bayes['min_split_gain'] = 0

# %% [markdown]
# #### 第6轮调参--scale_pos_weight

# %%
lgb_tune_df5 = lgb_tune1(fixed_params_bayes, 'scale_pos_weight', [i / 20 for i in range(20, 60, 1)], X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df5.sort_values('ks_oot',ascending=False)
# Out:
#       id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 1   1.05  0.224471  0.186603  0.192752  0.657812  0.621494  0.620082
# 34   2.7  0.237555  0.184273  0.191184  0.667056  0.623928  0.616534
# 18   1.9  0.234693  0.187681  0.191005  0.663786  0.622671  0.617386
# 22   2.1  0.233599  0.183174  0.190926  0.664936  0.623512  0.618471
# 15  1.75  0.234294   0.18292  0.189174  0.663288  0.622862  0.618608
# 31  2.55   0.23719  0.184715  0.188366  0.667373  0.623884  0.616865
# 36   2.8  0.239354  0.184021  0.188099  0.667124  0.624271  0.616931
# 7   0.040056   0.04196
# 39  0.056403  0.054327
# 0   0.042815  0.039911
# 28  0.055998  0.051577
# 4   0.041645  0.041844
# 12  0.044068  0.044434
# 5   0.042928  0.042998
# 21  0.043338  0.048364
# 9   0.037622  0.045079
# 17  0.043701  0.047149
# 14  0.047339  0.049219
# 33  0.053638  0.054514
# 23  0.043441  0.051897
# 10  0.043468  0.048357
# 37  0.054102  0.056465
# 35  0.054599  0.060382
# 24  0.047525  0.053997
# 25  0.046051   0.05553
# 13  0.047917  0.052313
# 8   0.043463  0.049513
# 16  0.044567  0.051256
# 6   0.035281  0.048825
# 11  0.046511  0.055482
# 38  0.054024  0.066909

# %%
fixed_params_bayes['scale_pos_weight'] = 1

# %% [markdown]
# #### 第7轮调参--random_state

# %%
lgb_tune_df6 = lgb_tune1(fixed_params_bayes, 'random_state', range(1, 100), X_train, y_train, X_test, y_test, X_oot, y_oot)
lgb_tune_df6.sort_values('ks_oot',ascending=False)
# Out:
#       id  ks_train   ks_test    ks_oot auc_train  auc_test   auc_oot  \
# 90  91.0  0.222456  0.186145  0.190092  0.657831  0.620903  0.618439
# 37  38.0  0.223802  0.185287  0.188431  0.657983  0.621992  0.618615
# 32  33.0  0.222534  0.182701  0.187837  0.657697  0.620361  0.618366
# 92  93.0  0.223227  0.183151  0.187814  0.657741  0.620792  0.617154
# 41  42.0  0.224747  0.185359  0.187618  0.657831  0.621987  0.618276
# ..   ...       ...       ...       ...       ...       ...       ...
# 95  96.0  0.224361   0.18646  0.177699  0.657112  0.621346  0.616118
# 68  69.0  0.223706   0.18506  0.177462  0.657919  0.621751  0.615257
# 45  46.0  0.223654  0.185414  0.177447  0.657267  0.621031  0.615301
# 46  47.0  0.224973   0.18177  0.177321  0.658335  0.620983  0.614943
# 40  41.0  0.225087  0.185577  0.175093  0.658091  0.620305  0.611783
#
#      ks_dec1   ks_dec2
# 90  0.036311  0.032364
# 37  0.038515  0.035371
# 32  0.039833  0.034697
# 92  0.040076  0.035413
# 41  0.039388  0.037129
# ..       ...       ...
# 95  0.037901  0.046662
# 68  0.038646  0.046244
# 45  0.038239  0.046207
# 46  0.043203  0.047652
# 40  0.039509  0.049994
#
# [99 rows x 9 columns]

# %%
fixed_params_bayes['random_state'] = 91

# %%
fixed_params_bayes
# Out:
# {'boosting_type': 'gbdt',
#  'max_depth': 3,
#  'learning_rate': 0.017,
#  'objective': 'binary',
#  'scale_pos_weight': 1,
#  'min_split_gain': 0,
#  'min_child_samples': 790,
#  'subsample': 0.8,
#  'colsample_bytree': 0.9,
#  'reg_lambda': 3,
#  'reg_alpha': 0,
#  'random_state': 91,
#  'force_col_wise': True,
#  'verbose': -1,
#  'n_estimators': 177}

# %% [markdown]
# ### RFE筛选变量

# %%
model = LGBMClassifier(**fixed_params_bayes)
model_eva(model, X_train, y_train, X_test, y_test, X_oot, y_oot, X_dev, y_dev, if_dev=True)
# Out:
# {'auc_train': 0.6449038162138588,
#  'auc_test': 0.6661840700083733,
#  'auc_oot': 0.6167619653097032,
#  'ks_train': 0.20762208800199738,
#  'ks_test': 0.24051000976656994,
#  'ks_oot': 0.1789301357938317,
#  'auc_dev': 0.6512914287170306,
#  'ks_dev': 0.2153762057967396}

# %%
model = LGBMClassifier(**fixed_params_bayes)
model_eva(model, X_train, y_train, X_test, y_test, X_oot, y_oot)
# Out:
# {'auc_train': 0.657831373978879,
#  'auc_test': 0.6209031730708443,
#  'auc_oot': 0.6184389340816632,
#  'ks_train': 0.2224559975800564,
#  'ks_test': 0.18614492067403526,
#  'ks_oot': 0.19009189154657807}

# %%
(model.feature_importances_ > 0).sum()
# Out:
# 139

# %%
rfe_feat = X_dev.columns[model.feature_importances_ > 0]

# %%
model_eva(model, X_train, y_train, X_test, y_test, X_oot, y_oot)
# Out:
# {'auc_train': 0.657831373978879,
#  'auc_test': 0.6209031730708443,
#  'auc_oot': 0.6184389340816632,
#  'ks_train': 0.2224559975800564,
#  'ks_test': 0.18614492067403526,
#  'ks_oot': 0.19009189154657807}

# %%
model = LGBMClassifier(**fixed_params_bayes)
feature_ranking, scores = filtering_feat_RFE(model, X_dev, y_dev, X_train, y_train, X_test, y_test, X_oot, y_oot)
feature_ranking.to_excel('feature_ranking_dev.xlsx', index=False)  # ranking从1开始
scores.to_excel('rfe_scores_dev.xlsx')

# %% [markdown]
# #### 选择k个特征

# %%
k = 72
final_cols = feature_ranking[feature_ranking['ranking'] <= k]['feature'].values
model_eva(model, X_train[final_cols], y_train, X_test[final_cols], y_test, X_oot[final_cols], y_oot)

# %%
model_eva(model, X_train[final_cols], y_train, X_test[final_cols], y_test, X_oot[final_cols], y_oot, X_dev[final_cols], y_dev, if_dev=True)

# %% [markdown]
# #### 查看每种类型所包含的变量数量

# %% [markdown]
# ### 保存模型

# %%
model.fit(X_dev[final_cols], y_dev)
model.feature_importances_
# Out:
# array([19, 29, 77, 23, 41, 27, 37, 21, 22, 26, 10, 22, 35, 16, 17,  8, 17,
#        22, 21, 29, 28, 26, 18, 17,  7, 18, 18, 12, 13, 15, 16, 16, 13, 16,
#        15, 17, 13,  8, 11,  7, 16, 11, 11, 14, 18, 13, 11, 11, 11, 14, 11,
#        11, 13, 11, 10,  8,  7, 13,  8,  9, 12, 10, 10,  6,  8,  7, 12,  5,
#         4,  6,  5,  5])

# %%
feature_df = lgb_shap_importance(model, X_dev[final_cols], X_oot[final_cols])
feature_df
# Out:
#    feature_name  dev_importance_shap  oot_importance_shap  importance_split  \
# 2           X67             0.099883             0.090816                77
# 6          ds16             0.039437             0.030132                37
# 4          ds61             0.031415             0.031145                41
# 12         k318             0.028120             0.090113                35
# 1           X93             0.018346             0.018853                29
# ..          ...                  ...                  ...               ...
# 57          311             0.001728             0.004647                13
# 55         2017             0.001498             0.001500                 8
# 65          183             0.001449             0.000981                 7
# 68          435             0.001103             0.001001                 4
# 70          X14             0.000424             0.000331                 5
#
#     importance_gain
# 2       5527.426035
# 6        932.805699
# 4        993.966118
# 12       850.662497
# 1        714.880214
# ..              ...
# 57       115.599818
# 55       111.411691
# 65       135.674501
# 68        92.208698
# 70        15.335830
#
# [72 rows x 5 columns]

# %%
(feature_df['importance_split'] == 0).sum()
# Out:
# 0

# %%
feature_df.to_excel('feature_importance_最终.xlsx')

# %%
import pickle 

# pickle.dump(model, open('ym202301.pkl', 'wb'))

# %% [markdown]
# ### 打分

# %%
KS(get_score(X_dev[final_cols], model)['score'], y_dev), KS(get_score(X_oot[final_cols], model)['score'], y_oot)
# Out:
# (0.2072856860027717, 0.18642023199556051)

# %%
X_all = pd.read_csv('data.csv').set_index(['uuid', 'certno', 'custname', 'phone', 'channel_flag', 'his_overdue_date', 'occur_date', 'payout_date'])[final_cols]

# %%
scores = get_score(X_all, model)
scores
# Out:
#                                                                                                                      好样本p  \
# uuid               certno             custname phone       channel_flag his_overdue_date occur_date payout_date
# 2204220000001954   430821198209255138 柴龙军      13327248768 升级贷-360      0                2022-04-22 2022-06-10   0.915713
# 2204240000002438   445323199103180912 张荣浩      13729781617 升级贷-360      0                2022-04-24 2022-04-27   0.934079
# 2204240000002870   420325198807111923 邢欢       18716135235 升级贷-360      0                2022-04-24 2022-04-24   0.956261
# 2204240000002885   34122519870702633X 徐洪春      13057958729 升级贷-360      0                2022-04-24 2022-04-24   0.931540
# 2204240000002939   410381198307016574 石自强      15139939738 升级贷-360      0                2022-04-24 2022-05-12   0.936659
# ...                                                                                                                   ...
# 650598090861707264 140481199105036416 张强       13623551709 升级贷-携程       0                2022-07-28 2022-07-28   0.945315
# 651017425794891776 610322199505103611 麻鹏玉      18292878448 升级贷-携程       0                2022-07-29 2022-07-29   0.922166
# 651461584930603008 440923198912132949 李晓瑜      13422666391 升级贷-携程       0                2022-07-30 2022-07-30   0.933039
# 651702203389313024 371523199005050056 戚迪       18365870387 升级贷-携程       0                2022-07-31 2022-07-31   0.949521
# 651908657920344064 152301199605085042 张晓雨      15004920005 升级贷-携程       0                2022-07-31 2022-07-31   0.909263
#
#                                                                                                                      坏样本p  \
# uuid               certno             custname phone       channel_flag his_overdue_date occur_date payout_date
# 2204220000001954   430821198209255138 柴龙军      13327248768 升级贷-360      0                2022-04-22 2022-06-10   0.084287
# 2204240000002438   445323199103180912 张荣浩      13729781617 升级贷-360      0                2022-04-24 2022-04-27   0.065921
# 2204240000002870   420325198807111923 邢欢       18716135235 升级贷-360      0                2022-04-24 2022-04-24   0.043739
# 2204240000002885   34122519870702633X 徐洪春      13057958729 升级贷-360      0                2022-04-24 2022-04-24   0.068460
# 2204240000002939   410381198307016574 石自强      15139939738 升级贷-360      0                2022-04-24 2022-05-12   0.063341
# ...                                                                                                                   ...
# 650598090861707264 140481199105036416 张强       13623551709 升级贷-携程       0                2022-07-28 2022-07-28   0.054685
# 651017425794891776 610322199505103611 麻鹏玉      18292878448 升级贷-携程       0                2022-07-29 2022-07-29   0.077834
# 651461584930603008 440923198912132949 李晓瑜      13422666391 升级贷-携程       0                2022-07-30 2022-07-30   0.066961
# 651702203389313024 371523199005050056 戚迪       18365870387 升级贷-携程       0                2022-07-31 2022-07-31   0.050479
# 651908657920344064 152301199605085042 张晓雨      15004920005 升级贷-携程       0                2022-07-31 2022-07-31   0.090737
#
#                                                                                                                      odds  \
# uuid               certno             custname phone       channel_flag his_overdue_date occur_date payout_date
# 2204220000001954   430821198209255138 柴龙军      13327248768 升级贷-360      0                2022-04-22 2022-06-10   0.092045
# 2204240000002438   445323199103180912 张荣浩      13729781617 升级贷-360      0                2022-04-24 2022-04-27   0.070573
# 2204240000002870   420325198807111923 邢欢       18716135235 升级贷-360      0                2022-04-24 2022-04-24   0.045740
# 2204240000002885   34122519870702633X 徐洪春      13057958729 升级贷-360      0                2022-04-24 2022-04-24   0.073491
# 2204240000002939   410381198307016574 石自强      15139939738 升级贷-360      0                2022-04-24 2022-05-12   0.067625
# ...                                                                                                                   ...
# 650598090861707264 140481199105036416 张强       13623551709 升级贷-携程       0                2022-07-28 2022-07-28   0.057848
# 651017425794891776 610322199505103611 麻鹏玉      18292878448 升级贷-携程       0                2022-07-29 2022-07-29   0.084403
# 651461584930603008 440923198912132949 李晓瑜      13422666391 升级贷-携程       0                2022-07-30 2022-07-30   0.071766
# 651702203389313024 371523199005050056 戚迪       18365870387 升级贷-携程       0                2022-07-31 2022-07-31   0.053162
# 651908657920344064 152301199605085042 张晓雨      15004920005 升级贷-携程       0                2022-07-31 2022-07-31   0.099792
#
#                                                                                                                  score
# uuid               certno             custname phone       channel_flag his_overdue_date occur_date payout_date
# 2204220000001954   430821198209255138 柴龙军      13327248768 升级贷-360      0                2022-04-22 2022-06-10   565.0
# 2204240000002438   445323199103180912 张荣浩      13729781617 升级贷-360      0                2022-04-24 2022-04-27   580.0
# 2204240000002870   420325198807111923 邢欢       18716135235 升级贷-360      0                2022-04-24 2022-04-24   605.0
# 2204240000002885   34122519870702633X 徐洪春      13057958729 升级贷-360      0                2022-04-24 2022-04-24   578.0
# 2204240000002939   410381198307016574 石自强      15139939738 升级贷-360      0                2022-04-24 2022-05-12   583.0
# ...                                                                                                                ...
# 650598090861707264 140481199105036416 张强       13623551709 升级贷-携程       0                2022-07-28 2022-07-28   592.0
# 651017425794891776 610322199505103611 麻鹏玉      18292878448 升级贷-携程       0                2022-07-29 2022-07-29   570.0
# 651461584930603008 440923198912132949 李晓瑜      13422666391 升级贷-携程       0                2022-07-30 2022-07-30   579.0
# 651702203389313024 371523199005050056 戚迪       18365870387 升级贷-携程       0                2022-07-31 2022-07-31   596.0
# 651908657920344064 152301199605085042 张晓雨      15004920005 升级贷-携程       0                2022-07-31 2022-07-31   560.0
#
# [92499 rows x 4 columns]

# %%
scores.to_excel('升级贷X_scores_92499.xlsx')

# %%
model
# Out:
# LGBMClassifier(colsample_bytree=0.9, force_col_wise=True, learning_rate=0.017,
#                max_depth=3, min_child_samples=790, min_split_gain=0,
#                n_estimators=177, objective='binary', random_state=91,
#                reg_alpha=0, reg_lambda=3, scale_pos_weight=1, subsample=0.8,
#                verbose=-1)
